# %%
with open("/mnt/d/forCoding_code/_init_tools/x__params.py", "r") as f:
    txt = f.read()
exec(txt)

with open("/mnt/d/forCoding_code/_init_tools/report_macro_0516.py", "r") as f:
    txt = f.read()
exec(txt)

with open("/mnt/d/forCoding_code/_init_tools/x__tool_here1.py", "r") as f:
    exec(f.read())
with open("/mnt/d/forCoding_code/_init_tools/x__tool_here2.py", "r") as f:
    exec(f.read())

wasted_dir = "./wasted"
if not os.path.exists(wasted_dir):
    os.makedirs(wasted_dir)

pd.set_option('display.max_rows',200)
pd.set_option('display.max_columns',200)
# Out:
# storage dir: /mnt/d/forCoding_data/Tianchi_Ecommerce6/plan_1
# code dir: /mnt/d/forCoding_code/Tianchi_Ecommerce6/plan_1

# %%
# !python train_cv.py --num_folds 5 --seed 42 --epochs_extract 5 --epochs_classify 5
# !python evaluate_f1_cv.py
# Out:
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Starting 5-fold CV training.
# Seed: 42
# Epochs (Extract): 1
# Epochs (Classify): 1
# Output Directory: /mnt/d/forCoding_data/Tianchi_Ecommerce6/plan_1/trained_models/cv
# Training Fold 1/5...
# Some weights of ExtractionModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ClassificationModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['cat_classifier.bias', 'cat_classifier.weight', 'pol_classifier.bias', 'pol_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training Fold 2/5...
# Some weights of ExtractionModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ClassificationModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['cat_classifier.bias', 'cat_classifier.weight', 'pol_classifier.bias', 'pol_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training Fold 3/5...
# Some weights of ExtractionModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ClassificationModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['cat_classifier.bias', 'cat_classifier.weight', 'pol_classifier.bias', 'pol_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training Fold 4/5...
# Some weights of ExtractionModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ClassificationModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['cat_classifier.bias', 'cat_classifier.weight', 'pol_classifier.bias', 'pol_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Training Fold 5/5...
# Some weights of ExtractionModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ClassificationModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['cat_classifier.bias', 'cat_classifier.weight', 'pol_classifier.bias', 'pol_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /home/xiuminke/miniconda3/envs/ml12/lib/python3.11/site-packages/torch/cuda/__init__.py:63: FutureWarning: The pynvml package is deprecated. Please install nvidia-ml-py instead. If you did not install pynvml directly, please report this to the maintainers of the package that installed pynvml for you.
#   import pynvml  # type: ignore[import]
# Some weights of ExtractionModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ClassificationModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['cat_classifier.bias', 'cat_classifier.weight', 'pol_classifier.bias', 'pol_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Fold extraction (fold_0): 100%|█████████████████| 41/41 [00:03<00:00, 10.73it/s]
# Fold classification (fold_0): 100%|███████████| 145/145 [00:12<00:00, 11.23it/s]
# ------------------------------
# Fold 0
# Correct (S): 899
# Predicted (P): 1268
# Ground Truth (G): 1314
# Precision: 0.7090
# Recall:    0.6842
# F1 Score:  0.6964
# Some weights of ExtractionModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ClassificationModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['cat_classifier.bias', 'cat_classifier.weight', 'pol_classifier.bias', 'pol_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Fold extraction (fold_1): 100%|█████████████████| 41/41 [00:04<00:00, 10.14it/s]
# Fold classification (fold_1): 100%|███████████| 144/144 [00:12<00:00, 11.16it/s]
# ------------------------------
# Fold 1
# Correct (S): 927
# Predicted (P): 1268
# Ground Truth (G): 1318
# Precision: 0.7311
# Recall:    0.7033
# F1 Score:  0.7169
# Some weights of ExtractionModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ClassificationModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['cat_classifier.bias', 'cat_classifier.weight', 'pol_classifier.bias', 'pol_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Fold extraction (fold_2): 100%|█████████████████| 41/41 [00:04<00:00, 10.08it/s]
# Fold classification (fold_2): 100%|███████████| 147/147 [00:13<00:00, 11.22it/s]
# ------------------------------
# Fold 2
# Correct (S): 897
# Predicted (P): 1289
# Ground Truth (G): 1325
# Precision: 0.6959
# Recall:    0.6770
# F1 Score:  0.6863
# Some weights of ExtractionModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ClassificationModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['cat_classifier.bias', 'cat_classifier.weight', 'pol_classifier.bias', 'pol_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Fold extraction (fold_3): 100%|█████████████████| 41/41 [00:03<00:00, 10.39it/s]
# Fold classification (fold_3): 100%|███████████| 152/152 [00:13<00:00, 11.18it/s]
# ------------------------------
# Fold 3
# Correct (S): 928
# Predicted (P): 1315
# Ground Truth (G): 1348
# Precision: 0.7057
# Recall:    0.6884
# F1 Score:  0.6970
# Some weights of ExtractionModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Some weights of ClassificationModel were not initialized from the model checkpoint at /mnt/d/ModelScopeModels/google-bert/bert-base-chinese/ and are newly initialized: ['cat_classifier.bias', 'cat_classifier.weight', 'pol_classifier.bias', 'pol_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Fold extraction (fold_4): 100%|█████████████████| 41/41 [00:03<00:00, 10.45it/s]
# Fold classification (fold_4): 100%|███████████| 150/150 [00:13<00:00, 11.17it/s]
# ------------------------------
# Fold 4
# Correct (S): 984
# Predicted (P): 1373
# Ground Truth (G): 1327
# Precision: 0.7167
# Recall:    0.7415
# F1 Score:  0.7289
# ==============================
# CV Overall
# Correct (S): 4635
# Predicted (P): 6513
# Ground Truth (G): 6632
# ==============================
# Precision: 0.7117
# Recall:    0.6989
# F1 Score:  0.7052
# ==============================

# %% [raw]
# CV Overall
# Correct (S): 4635
# Predicted (P): 6513
# Ground Truth (G): 6632
# ==============================
# Precision: 0.7117
# Recall:    0.6989
# F1 Score:  0.7052
# ==============================

# %%
# !sh run.sh

# %% [markdown]
# 【TODO】~~增大轮数~~，难样本挖掘，数据增强，使用新的数据（可能借助大模型），换模型。
#
# 【TODO】polarity中性的样本，换一种处理方式？
